# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_excel("C:\\Users\\ASUS\\Downloads\\CVD.xlsx") #sesuaikan path

# %%
df2 = pd.read_excel("C:\\Users\\ASUS\\Downloads\\DKI.xlsx") #sesuaikan path

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586 entries, 0 to 585
# Data columns (total 94 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Unnamed: 0                                         567 non-null    datetime64[ns]
#  1   Kasus harian                                       567 non-null    float64
#  2   Kasus Impor                                        10 non-null     float64
#  3   Kasus Lokal                                        10 non-null     float64
#  4   Total kasus                                        567 non-null    float64
#  5   Kasus aktif                                        567 non-null    float64
#  6   % kasus aktif                                      567 non-null    float64
#  7   Sembuh
# (baru)                                      567 non-null    float64
# ...

# %%
df1 = df1.drop(['Orang yang dites (Antigen)', 'Orang yang dites (PCR-TCM)', 'Pos Rate DKI', 'Dosis ketiga (SDM kesehatan)',
               'Rasio spesimen/orang diperiksa (rata-rata 7 hari)', 'Jumlah orang diperiksa (rata-rata 7 hari)', 
               'Jumlah spesimen diperiksa (rata-rata 7 hari)', 'Pos Rate Non DKI', 'Pos Rate Non DKI - 7 harian', 
               'Pos Rate DKI - 7 harian', 'Pos Rate DKI - 7 harian', 'Pos Rate Nasional - rata-rata 7 hari',
               'Test PCR Orang Nasional Rata-rata 7 hari'], axis=1)

# %%
df1 = df1.drop(['Unnamed: 85', 'Unnamed: 86', 'Unnamed: 87', 'Unnamed: 88', 'Unnamed: 89',
                'Unnamed: 90', 'Unnamed: 91', 'Unnamed: 92', 'Unnamed: 93',
                'PDP', 'ODP', 'Spesimen','Spesimen (PCR-TCM)', 'Spesimen (Antigen)', 'Vaksinasi (ineligible)'], axis=1)

# %%
df1.rename(columns={'Unnamed: 0':'Tanggal'}, inplace=True)

# %%
df1.rename(columns={'Kasus harian':'Kasus_harian', 'Kasus Impor':'Kasus_impor', 'Kasus Lokal':'Kasus_lokal',
                   'Total kasus':'Total_kasus', 'Kasus aktif':'Kasus_aktif', 'Sembuh\n(baru)':'Sembuh(baru)', 
                    'Meninggal\n(baru)' : 'Meninggal(baru)', 'Meninggal\nDunia':'Meninggal',
                   'Tingkat kesembuhan (seluruh kasus)':'Tingkat_kesembuhan(seluruh kasus)', 
                    'Tingkat kematian (seluruh kasus)' : 'Tingkat_kematian(seluruh kasus)'},inplace=True)

# %%
df1.rename(columns={'Tingkat kesembuhan (closed cases)':'Tingkat_kesembuhan(closed cases)', 
                   'Tingkat kematian (closed cases)' : 'Tingkat_kematian(closed cases)',
                   'Positive rate harian':'Positive_rate_harian', ' % kasus aktif':' %kasus_aktif', 'Suspek aktif':'Suspek_aktif', 
                    'Dosis pertama':'Dosis_pertama', 'Dosis kedua':'Dosis_kedua'},inplace=True)

# %%
df1.rename(columns={'Dosis pertama (%)':'Dosis_pertama(%)', 'Dosis kedua (%)':'Dosis_kedua(%)', 
                    'Dosis pertama (harian)':'Dosis_pertama(harian)', 
                    'Dosis kedua (harian)':'Dosis_kedua(harian)'},inplace=True)

# %%
df1.rename(columns={'Positif \n(=C)':'Positif', 'Dosis harian':'Dosis_harian', 
                    'Test Orang DKI':'Test_Orang_DKI', 'Positif DKI':'Positif_DKI', 
                    'NON DKI':'NON_DKI', 'Positif Non DKI':'Positif_Non_DKI',
                   'Rata2 dosis harian (mingguan)':'Rata2_dosis_harian_mingguan', 
                    'Dosis pertama (SDM kesehatan) %':'Dosis_pertama(medis)_%', 
                    'Dosis kedua (SDM kesehatan) %':'Dosis_kedua(medis)_%'},inplace=True)

# %%
df1.rename(columns={'Dosis pertama (petugas publik)':'Dosis_pertama(pns)', 'Dosis kedua(petugas publik)':'Dosis_kedua(pns)', 
                   'Dosis pertama (petugas publik) %':'Dosis_pertama(pns)_%', 
                   'Dosis kedua (petugas publik) %':'Dosis_kedua(pns)_%'},inplace=True)

# %%
df1.rename(columns={'Dosis pertama (lansia)':'Dosis_pertama(lansia)', 
                   'Dosis kedua(lansia)':'Dosis_kedua(lansia)', 'Dosis pertama (lansia) %':'Dosis_pertama(lansia)_%', 
                   'Dosis kedua (lansia) %':'Dosis_kedua(lansia)_%',
                   'Dosis pertama (warga umum)':'Dosis_pertama(warga)', 'Dosis kedua(warga umum)':'Dosis_kedua(warga)', 
                    'Dosis pertama (remaja)':'Dosis_pertama(remaja)', 'Dosis kedua (remaja) %':'Dosis_kedua(remaja)'},inplace=True)

# %%
df1.rename(columns={'Dosis kedua':'Dosis_kedua', 'Jumlah spesimen diperiksa (dari 1 April)':'Jumlah_spesimen_diperiksa(dari 1 April)', 
                    'Jumlah orang diperiksa':'Jumlah_orang_diperiksa', 'Orang yang dites':'Orang_yang_dites'}, inplace=True)

# %%
df1.rename(columns={'Jumlah test/juta penduduk':'Jumlah_test_penduduk', 'Jumlah Test/Positif harian':'JumlahTest/Positif harian'},
inplace=True)

# %%
df1 = df1.drop(['Test_Orang_DKI', 'Positif_DKI', 'Unnamed: 76', 'NON_DKI', 'Positif_Non_DKI',
               'Unnamed: 81', 'CFR'], axis=1)

# %%
df1 = df1.drop(['Kasus_impor', 'Kasus_lokal'], axis=1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tanggal          570 non-null    datetime64[ns]
#  1   Jam              550 non-null    object
#  2   Tanggal Jam      569 non-null    object
#  3   Meninggal        570 non-null    int64
#  4   Sembuh           570 non-null    int64
#  5   Self Isolation   570 non-null    int64
#  6   Masih Perawatan  570 non-null    int64
#  7   Total Pasien     570 non-null    int64
#  8   Positif Harian   570 non-null    int64
#  9   Positif Aktif    570 non-null    int64
#  10  Sembuh Harian    570 non-null    int64
#  11  Tanpa Gejala     430 non-null    float64
#  12  Bergejala        430 non-null    float64
#  13  Belum Ada Data   430 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(8), object(2)
# memory usage: 62.5+ KB

# %%
df2.rename(columns={'Tanggal Jam':'Tanggal_jam', 'Self Isolation':'Self_isolation', 'Masih Perawatan':'Masih_perawatan', 'Total Pasien':'Total_pasien',
                  'Positif Harian':'Positif_harian', 'Positif Aktif':'Positif_aktif', 'Sembuh Harian':'Sembuh_harian', 'Tanpa Gejala':'Tanpa_gejala',
                  'Belum Ada Data':'Belum_ada_data'}, inplace=True)

# %%
df2 = df2.drop(['Belum_ada_data', 'Tanggal_jam'], axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586 entries, 0 to 585
# Data columns (total 58 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Tanggal                                  567 non-null    datetime64[ns]
#  1   Kasus_harian                             567 non-null    float64
#  2   Total_kasus                              567 non-null    float64
#  3   Kasus_aktif                              567 non-null    float64
#  4   % kasus aktif                            567 non-null    float64
#  5   Sembuh(baru)                             567 non-null    float64
#  6   Sembuh                                   567 non-null    float64
#  7   Tingkat_kesembuhan(seluruh kasus)        567 non-null    float64
#  8   Tingkat_kesembuhan(closed cases)         559 non-null    float64
#  9   Meninggal(baru)                          567 non-null    float64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tanggal          570 non-null    datetime64[ns]
#  1   Jam              550 non-null    object
#  2   Meninggal        570 non-null    int64
#  3   Sembuh           570 non-null    int64
#  4   Self_isolation   570 non-null    int64
#  5   Masih_perawatan  570 non-null    int64
#  6   Total_pasien     570 non-null    int64
#  7   Positif_harian   570 non-null    int64
#  8   Positif_aktif    570 non-null    int64
#  9   Sembuh_harian    570 non-null    int64
#  10  Tanpa_gejala     430 non-null    float64
#  11  Bergejala        430 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(8), object(1)
# memory usage: 53.6+ KB

# %%
sns.boxplot(data=df2, x="Positif_aktif")
# Out:
# <AxesSubplot:xlabel='Positif_aktif'>

# %% [markdown]
# Persebaran data Positif Aktif untuk daerah DKI Jakarta

# %%
sns.boxplot(data=df1, x="Kasus_aktif")
# Out:
# <AxesSubplot:xlabel='Kasus_aktif'>

# %% [markdown]
# Persebaran data Positif Aktif untuk daerah Indonesia

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(30, 10))

# Add x-axis and y-axis
ax.plot(df1['Tanggal'],
        df1['Kasus_aktif'],
        color='purple',label = "Positif Covid Aktif di Indonesia")

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Total Positif",
       title="Positif Covid Aktif di Indonesia")

plt.show()

# %% [markdown]
# dari plot diatas, dapat kita lihat bahwa kasus positif aktif di Indonesia mengalami penurunan dari pertengahan
# bulan 7 (Juli) hingga bulan 9 (September/saat ini). Dimana pada rentang itu pemerintah Indonesia melaksanakan ppkm
# Dari data di atas bisa kita simpulkan bahwa ppkm efektif dalam menurunkan kasus positf aktif di Indonesia

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(30, 10))

# Add x-axis and y-axis
ax.plot(df1['Tanggal'],
        df1['Dosis_pertama(%)'],
        color='purple',label = "Case Growth Rate Indonesia")
# Add x-axis and y-axis
ax.plot(df1['Tanggal'],
        df1['Dosis_kedua(%)'],
        color='red',label = "Case Growth Rate Indonesia")
# Add x-axis and y-axis
ax.plot(df1['Tanggal'],
        df1['Case Growth Rate'],
        color='green',label = "Case Growth Rate Indonesia")
    
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Total Positif",
       title="Case Growth Rate Indonesia")

plt.show()

# %% [markdown]
# Case growth rate di Indonesia menurun sejak pengadaan vaksinasi di Indonesia

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(30, 10))

# Add x-axis and y-axis
ax.plot(df1['Tanggal'],
        df1['Dosis_pertama'],
        color='purple',label = "Dosis Pertama")
# Add x-axis and y-axis
ax.plot(df1['Tanggal'],
        df1['Dosis_kedua'],
        color='red',label = "Dosis Kedua")
# Add x-axis and y-axis
ax.plot(df1['Tanggal'],
        df1['Kasus_harian'],
        color='green',label = "Kasus Harian")
    
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Total Data",
       title="Persebaran kasus harian")

plt.show()

# %%
df1.Kasus_harian.describe()
# Out:
# count      567.000000
# mean      7394.511464
# std       9917.736733
# min          0.000000
# 25%       1680.000000
# 50%       4497.000000
# 75%       7436.000000
# max      56757.000000
# Name: Kasus_harian, dtype: float64

# %% [markdown]
# Catatan kasus harian menurun sejak persebaran vaksinasi di Indonesia dimulai
# Dimana kasus harian tertinggi yang tercatat di Indonesia mencapai 56.757 kasus baru

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(30, 10))

# Add x-axis and y-axis
ax.plot(df1['Tanggal'],
        df1['Tingkat_kesembuhan(seluruh kasus)'],
        color='green',label = "Tingkat Kesembuhan")
# Add x-axis and y-axis
ax.plot(df1['Tanggal'],
        df1['Tingkat_kematian(seluruh kasus)'],
        color='red',label = "Tingkat Kematian")
    
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Total Data",
       title="Perbandingan Tingkat Kesembuhan dengan Tingkat Kematian")

plt.show()

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(30, 10))

# Add x-axis and y-axis
ax.plot(df1['Tanggal'],
        df1['Sembuh(baru)'],
        color='green',label = "Kasus Sembuh harian")
# Add x-axis and y-axis
ax.plot(df1['Tanggal'],
        df1['Meninggal(baru)'],
        color='red',label = "Kasus Meninggal harian")
    
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Total Data",
       title="Perbandingan Kasus Sembuh Harian dengan Kasus Meninggal Harian")

plt.show()

# %% [markdown]
# Dapat dilihat dari dua subplot di atas, bahwa tingkat kesembuhan pasien covid jauh lebih besar dibandingkan tingkat kematian pasien covid
# Begitu pula pada pasien covid yang sembuh (harian) selalu lebih banyak dibandingkan kasus kematian pasien (harian)

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(30, 10))

# Add x-axis and y-axis
ax.plot(df2['Tanggal'],
        df2['Positif_aktif'],
        color='purple',label = "Kasus Aktif Jakarta")
# Add x-axis and y-axis
ax.plot(df1['Tanggal'],
        df1['Kasus_aktif'],
        color='green',label = "Kasus Aktif Indonesia")
    
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Total Kasus",
       title="Perbandingan Kasus Aktif Indonesia dengan DKI Jakarta")

plt.show()

# %% [markdown]
# Dapat dilihat dari data diatas, pada awal pandemi kasus aktif di Indonesia bersinggungan dengan kasus aktif di DKI Jakarta. Yang berarti persebaran kasus aktif pertama di Indonesia berada di DKI Jakarta

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(30, 10))


# Add x-axis and y-axis
ax.plot(df2['Tanggal'],
        df2['Bergejala'],
        color='green',label = "Pasien Bergejala")
ax.plot(df2['Tanggal'],
        df2['Tanpa_gejala'],
        color='orange',label = "Pasien Tanpa Gejala")


# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Pasien",
       title="Perbandingan Pasien Bergejala dengan Pasien Tanpa Gejala di Jakarta")
# Out:
# [Text(0.5, 0, 'Date'),
#  Text(0, 0.5, 'Pasien'),
#  Text(0.5, 1.0, 'Perbandingan Pasien Bergejala dengan Pasien Tanpa Gejala di Jakarta')]

# %% [markdown]
# Pada awal pandemi, Pasien tanpa gejala lebih banyak dijumpai. Sedangkan mulai tahun 2021, kebanyakan pasien yang terkonfirmasi positif memiliki gejala-gejala covid

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(30, 10))


# Add x-axis and y-axis
ax.plot(df2['Tanggal'],
        df2['Self_isolation'],
        color='green',label = "Self Isolation")
ax.plot(df2['Tanggal'],
        df2['Masih_perawatan'],
        color='orange',label = "Dalam Perawatan")


# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Jumlah Kasus",
       title="Perbandingan Pasien Self-Isolation dengan Pasien Rawat Inap di DKI Jakarta")
# Out:
# [Text(0.5, 0, 'Date'),
#  Text(0, 0.5, 'Jumlah Kasus'),
#  Text(0.5, 1.0, 'Perbandingan Pasien Self-Isolation dengan Pasien Rawat Inap di DKI Jakarta')]

# %% [markdown]
# Dari data bisa kita simpulkan bahwa masyarakat DKI Jakarta lebih memilih untuk menjalani treatment mandiri di rumah ketimbang mendapatkan treatment di RS.
